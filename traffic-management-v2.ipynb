# %% [markdown]
# # **Step 1: Setup and Unzip Archive Folder**

# %%
# %cd /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5
# %pwd
# Out:
# /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5
# '/home/venky/Documents/class/Application_of_neural_networks/Project/yolov5'

# %% [markdown]
# # Setup local Paths

# %%
import os

# Define local paths for the dataset
base_path = 'content/UA-DETRAC/DETRAC_Upload'

train_image_path = os.path.join(base_path, 'images/train')
val_image_path = os.path.join(base_path, 'images/val')

train_label_path = os.path.join(base_path, 'labels/train')
val_label_path = os.path.join(base_path, 'labels/val')

# Print paths to verify
print(f"Train images path: {train_image_path}")
print(f"Validation images path: {val_image_path}")
print(f"Train labels path: {train_label_path}")
print(f"Validation labels path: {val_label_path}")
# Out:
# Train images path: content/UA-DETRAC/DETRAC_Upload/images/train
# Validation images path: content/UA-DETRAC/DETRAC_Upload/images/val
# Train labels path: content/UA-DETRAC/DETRAC_Upload/labels/train
# Validation labels path: content/UA-DETRAC/DETRAC_Upload/labels/val

# %% [markdown]
# # **Step 2: Preprocessing the Images with Progress Prints**

# %%
from PIL import Image
import os

# Convert images to JPG if necessary and provide progress feedback
def convert_images_to_jpg(folder_path):
    total_files = len(os.listdir(folder_path))
    for idx, filename in enumerate(os.listdir(folder_path)):
        if not filename.endswith('.jpg'):
            img = Image.open(os.path.join(folder_path, filename))
            img.convert('RGB').save(os.path.join(folder_path, os.path.splitext(filename)[0] + '.jpg'), 'JPEG')
            os.remove(os.path.join(folder_path, filename))  # Remove old file
        if idx % 5000 == 0:  # Print progress every 5000 images
            print(f"Processed {idx}/{total_files} images in {folder_path}")

print("Converting train images...")
convert_images_to_jpg(train_image_path)

print("Converting validation images...")
convert_images_to_jpg(val_image_path)

# Verify annotations format with progress prints
def check_labels(label_folder):
    total_labels = len(os.listdir(label_folder))
    for idx, label_file in enumerate(os.listdir(label_folder)):
        with open(os.path.join(label_folder, label_file), 'r') as file:
            for line in file.readlines():
                values = line.strip().split(' ')
                assert len(values) == 5, f"Incorrect label format in {label_file}"
        if idx % 5000 == 0:  # Print progress every 5000 labels
            print(f"Verified {idx}/{total_labels} label files in {label_folder}")

print("Verifying train labels...")
check_labels(train_label_path)

print("Verifying validation labels...")
check_labels(val_label_path)

print("Data preprocessing complete!")
# Out:
# Converting train images...
# Processed 0/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 5000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 10000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 15000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 20000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 25000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 30000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 35000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 40000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 45000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 50000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 55000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 60000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 65000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 70000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 75000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Processed 80000/83791 images in content/UA-DETRAC/DETRAC_Upload/images/train
# Converting validation images...
# Processed 0/56340 images in content/UA-DETRAC/DETRAC_Upload/images/val
# Processed 5000/56340 images in content/UA-DETRAC/DETRAC_Upload/images/val
# Processed 10000/56340 images in content/UA-DETRAC/DETRAC_Upload/images/val
# Processed 15000/56340 images in content/UA-DETRAC/DETRAC_Upload/images/val
# Processed 20000/56340 images in content/UA-DETRAC/DETRAC_Upload/images/val
# Processed 25000/56340 images in content/UA-DETRAC/DETRAC_Upload/images/val
# Processed 30000/56340 images in content/UA-DETRAC/DETRAC_Upload/images/val
# Processed 35000/56340 images in content/UA-DETRAC/DETRAC_Upload/images/val
# Processed 40000/56340 images in content/UA-DETRAC/DETRAC_Upload/images/val
# Processed 45000/56340 images in content/UA-DETRAC/DETRAC_Upload/images/val
# Processed 50000/56340 images in content/UA-DETRAC/DETRAC_Upload/images/val
# Processed 55000/56340 images in content/UA-DETRAC/DETRAC_Upload/images/val
# Verifying train labels...
# Verified 0/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 5000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 10000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 15000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 20000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 25000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 30000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 35000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 40000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 45000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 50000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 55000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 60000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 65000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 70000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 75000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verified 80000/82085 label files in content/UA-DETRAC/DETRAC_Upload/labels/train
# Verifying validation labels...
# Verified 0/56167 label files in content/UA-DETRAC/DETRAC_Upload/labels/val
# Verified 5000/56167 label files in content/UA-DETRAC/DETRAC_Upload/labels/val
# Verified 10000/56167 label files in content/UA-DETRAC/DETRAC_Upload/labels/val
# Verified 15000/56167 label files in content/UA-DETRAC/DETRAC_Upload/labels/val
# Verified 20000/56167 label files in content/UA-DETRAC/DETRAC_Upload/labels/val
# Verified 25000/56167 label files in content/UA-DETRAC/DETRAC_Upload/labels/val
# Verified 30000/56167 label files in content/UA-DETRAC/DETRAC_Upload/labels/val
# Verified 35000/56167 label files in content/UA-DETRAC/DETRAC_Upload/labels/val
# Verified 40000/56167 label files in content/UA-DETRAC/DETRAC_Upload/labels/val
# Verified 45000/56167 label files in content/UA-DETRAC/DETRAC_Upload/labels/val
# Verified 50000/56167 label files in content/UA-DETRAC/DETRAC_Upload/labels/val
# Verified 55000/56167 label files in content/UA-DETRAC/DETRAC_Upload/labels/val
# Data preprocessing complete!

# %% [markdown]
# # **Step 3: Install YOLOv5**

# %%
# Install YOLOv5 dependencies
#!git clone https://github.com/ultralytics/yolov5  # Clone YOLOv5 repository
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17067, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 17067 (delta 24), reused 27 (delta 12), pack-reused 17022 (from 1)
# Receiving objects: 100% (17067/17067), 15.69 MiB | 1.29 MiB/s, done.
# Resolving deltas: 100% (11718/11718), done.

# %%
# %cd yolov5
# Out:
# /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5

# %% [markdown]
# # Installing the Required Libraries

# %%
#!pip install -r requirements.txt  # Install required Python packages
# Out:
# Collecting gitpython>=3.1.30 (from -r requirements.txt (line 5))
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: matplotlib>=3.3 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (3.9.2)
# Requirement already satisfied: numpy>=1.23.5 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (2.1.3)
# Collecting opencv-python>=4.1.1 (from -r requirements.txt (line 8))
#   Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=10.3.0 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (11.0.0)
# Requirement already satisfied: psutil in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (6.1.0)
# Collecting PyYAML>=5.3.1 (from -r requirements.txt (line 11))
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting requests>=2.32.2 (from -r requirements.txt (line 12))
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: scipy>=1.4.1 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (1.14.1)
# Collecting thop>=0.1.1 (from -r requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Collecting torch>=1.8.0 (from -r requirements.txt (line 15))
#   Using cached torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchvision>=0.9.0 (from -r requirements.txt (line 16))
#   Using cached torchvision-0.20.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.1 kB)
# Collecting tqdm>=4.66.3 (from -r requirements.txt (line 17))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting ultralytics>=8.2.34 (from -r requirements.txt (line 18))
#   Downloading ultralytics-8.3.40-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: pandas>=1.1.4 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (2.2.3)
# Collecting seaborn>=0.11.0 (from -r requirements.txt (line 28))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: setuptools>=70.0.0 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from -r requirements.txt (line 42)) (75.1.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->-r requirements.txt (line 5))
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.32.2->-r requirements.txt (line 12))
#   Downloading charset_normalizer-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.32.2->-r requirements.txt (line 12))
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.32.2->-r requirements.txt (line 12))
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.32.2->-r requirements.txt (line 12))
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting filelock (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.12.2)
# Collecting networkx (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=1.8.0->-r requirements.txt (line 15))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting py-cpuinfo (from ultralytics>=8.2.34->-r requirements.txt (line 18))
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics>=8.2.34->-r requirements.txt (line 18))
#   Downloading ultralytics_thop-2.0.12-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5))
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: six>=1.5 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
# Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 389.8 kB/s eta 0:00:00a 0:00:01
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Using cached torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl (906.4 MB)
# Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
# Using cached torchvision-0.20.1-cp310-cp310-manylinux1_x86_64.whl (7.2 MB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading ultralytics-8.3.40-py3-none-any.whl (898 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.5/898.5 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading ultralytics_thop-2.0.12-py3-none-any.whl (26 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 908.2 kB/s eta 0:00:00a 0:00:01
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: py-cpuinfo, mpmath, urllib3, tqdm, sympy, smmap, PyYAML, opencv-python, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, MarkupSafe, idna, fsspec, filelock, charset-normalizer, certifi, triton, requests, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, gitdb, seaborn, nvidia-cusolver-cu12, gitpython, torch, ultralytics-thop, torchvision, thop, ultralytics
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
# Successfully installed MarkupSafe-3.0.2 PyYAML-6.0.2 certifi-2024.8.30 charset-normalizer-3.4.0 filelock-3.16.1 fsspec-2024.10.0 gitdb-4.0.11 gitpython-3.1.43 idna-3.10 jinja2-3.1.4 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 opencv-python-4.10.0.84 py-cpuinfo-9.0.0 requests-2.32.3 seaborn-0.13.2 smmap-5.0.1 sympy-1.13.1 thop-0.1.1.post2209072238 torch-2.5.1 torchvision-0.20.1 tqdm-4.67.1 triton-3.1.0 ultralytics-8.3.40 ultralytics-thop-2.0.12 urllib3-2.2.3

# %%
# If you encounter issues, you might need to install additional packages
#!pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: torchvision in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (0.20.1)
# Requirement already satisfied: filelock in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torchvision) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)

# %% [markdown]
# # **Step 4: Training YOLOv5**

# %%
# Create the folder named 'Detrac'
os.makedirs('Detrac_File', exist_ok=True)

# Create the detrac.yaml file with the required structure
detrac_yaml_content = """
train: content/UA-DETRAC/DETRAC_Upload/images/train
val: content/UA-DETRAC/DETRAC_Upload/images/val
nc: 4 # Number of classes
names:
  0: "class0"
  1: "class1"
  2: "class2"
  3: "class3"
"""

# Write the content to a new detrac.yaml file in the Detrac folder
with open('Detrac_File/detrac.yaml', 'w') as f:
    f.write(detrac_yaml_content)

print("detrac.yaml created successfully!")
# Out:
# detrac.yaml created successfully!

# %%
# !python train.py --img 416 --batch 16 --epochs 20 --data Detrac_File/detrac.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=Detrac_File/detrac.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=2, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-388-g882c35fc Python-3.10.15 torch-2.5.1+cu124 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=4
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     24273  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7030417 parameters, 7030417 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning /home/venky/Documents/class/Application_of_neural_networks/Proje
# val: Scanning /home/venky/Documents/class/Application_of_neural_networks/Project
#
# AutoAnchor: 4.80 anchors/target, 0.999 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp9/labels.jpg...
# /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to runs/train/exp9
# Starting training for 2 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/5237 [00:00<?, ?it/s]/home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G      0.131    0.03324    0.04864        174        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1302    0.03703    0.04826        210        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1295    0.03534    0.04803        146        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1296    0.03383    0.04789        128        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1295    0.03419    0.04777        180        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1296    0.03585    0.04763        260        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1292    0.03678    0.04741        194        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1291    0.03757    0.04736        213        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G      0.129     0.0376    0.04724        180        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1289    0.03829    0.04707        218        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1289    0.03879    0.04696        223        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1288    0.03903    0.04684        180        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1287    0.03923    0.04674        179        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1288    0.03893    0.04661        179        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1288    0.03961    0.04647        256        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1287    0.03969    0.04634        181        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1286    0.03984    0.04623        181        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1285    0.03996    0.04615        186        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1283    0.04017    0.04604        172        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1282    0.04091    0.04589        256        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1281     0.0408    0.04575        155        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1281    0.04124    0.04561        260        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G      0.128    0.04169    0.04551        239        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1279    0.04252     0.0454        291        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1279    0.04252    0.04529        199        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1278    0.04256    0.04519        204        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1277    0.04269    0.04511        212        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1276    0.04267      0.045        180        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1275    0.04286    0.04493        240        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1275    0.04297    0.04479        227        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1274    0.04303    0.04469        203        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1273    0.04305    0.04458        201        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1272    0.04315    0.04445        194        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1271     0.0433    0.04436        213        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G      0.127    0.04335    0.04425        173        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1269    0.04344    0.04412        185        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1268    0.04318    0.04402        135        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1267    0.04327     0.0439        200        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1266    0.04365    0.04381        244        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1266    0.04363    0.04372        168        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1265    0.04403    0.04363        270        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1265    0.04427    0.04353        247        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1264    0.04436    0.04343        198        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1263     0.0446    0.04332        218        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1262     0.0447    0.04326        191        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1261    0.04468    0.04317        144        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G      0.126    0.04482    0.04309        226        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G      0.126     0.0451    0.04299        237        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1259    0.04542    0.04291        289        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1258    0.04528    0.04283        141        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1257     0.0453    0.04274        156        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1256    0.04541    0.04265        175        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1255     0.0455    0.04257        196        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1254    0.04565    0.04247        235        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1253    0.04598     0.0424        244        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1253     0.0461     0.0423        226        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1252    0.04612    0.04221        167        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1252     0.0463    0.04214        266        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1251    0.04621    0.04206        137        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G      0.125    0.04637    0.04197        215        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1249     0.0466    0.04187        210        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1248    0.04672    0.04177        217        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1247    0.04678    0.04166        196        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1247    0.04686    0.04158        226        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1247    0.04686     0.0415        193        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1246    0.04682    0.04141        169        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1245     0.0469    0.04135        184        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1245      0.047    0.04125        220        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1244    0.04719    0.04117        235        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1243    0.04723    0.04107        183        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1243    0.04724    0.04098        168        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1242    0.04741    0.04092        229        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1241    0.04752    0.04085        197        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1241    0.04758    0.04078        194        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G      0.124    0.04766     0.0407        206        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1239    0.04769    0.04061        192        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1239    0.04781    0.04055        218        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1238    0.04789    0.04047        195        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1237    0.04798    0.04039        212        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1236    0.04801    0.04034        165        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1236    0.04815    0.04027        222        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1235    0.04818    0.04021        175        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1235    0.04837    0.04015        264        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1235    0.04852    0.04008        265        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1234    0.04864    0.03999        232        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1234     0.0487    0.03992        210        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1233    0.04877    0.03983        203        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1233    0.04876    0.03976        183        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1232    0.04893    0.03969        222        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1231    0.04906    0.03962        265        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1231     0.0491    0.03955        176        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G      0.123    0.04922    0.03948        246        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1229    0.04929    0.03943        183        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1229    0.04946    0.03939        286        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1229    0.04959    0.03932        235        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1228    0.04968    0.03924        205        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1227    0.04985    0.03918        262        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1227    0.04982    0.03914        206        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1227    0.04985    0.03906        232        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1226    0.04994    0.03901        213        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1225    0.04998    0.03896        180        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1225    0.05002     0.0389        201        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1224    0.05006    0.03885        176        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1223    0.05017    0.03879        199        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1223    0.05016    0.03875        168        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1222    0.05012    0.03867        166        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1222    0.05021    0.03861        229        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1221    0.05025    0.03853        202        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1221     0.0503    0.03847        229        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G      0.122    0.05042    0.03841        244        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1219    0.05049    0.03834        184        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1219    0.05054    0.03829        237        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1218    0.05051    0.03823        158        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1218    0.05055    0.03818        199        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1217    0.05055    0.03812        174        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1217    0.05065    0.03807        229        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1216     0.0508    0.03802        247        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1216    0.05086    0.03797        216        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1215    0.05083    0.03792        182        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1215     0.0509    0.03785        224        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1214    0.05095     0.0378        235        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1214    0.05105    0.03775        212        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1213    0.05107    0.03769        206        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1213     0.0511    0.03763        200        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1212    0.05112    0.03757        173        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1212    0.05122    0.03754        275        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1211    0.05126    0.03748        188        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.1211    0.05133    0.03743        227        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G      0.121    0.05139    0.03739        228        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06129    0.04648    0.02157        202        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06128    0.04648    0.02156        153        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06127    0.04648    0.02156        266        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06126    0.04648    0.02156        248        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06125    0.04647    0.02155        182        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06124    0.04647    0.02155        260        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06123    0.04647    0.02154        237        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06122    0.04647    0.02154        238        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.0612    0.04647    0.02154        215        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06119    0.04646    0.02153        217        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06118    0.04646    0.02153        159        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06117    0.04645    0.02152        170        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06116    0.04645    0.02152        181        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06114    0.04644    0.02152        177        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06113    0.04643    0.02151        172        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06112    0.04643    0.02151        201        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06111    0.04643     0.0215        246        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.0611    0.04642     0.0215        215        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06109    0.04642    0.02149        238        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06107    0.04642    0.02149        176        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06106    0.04641    0.02149        163        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06105    0.04641    0.02148        203        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06104     0.0464    0.02148        141        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06103    0.04639    0.02148        197        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06102    0.04639    0.02147        205        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06101    0.04639    0.02147        227        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G      0.061    0.04639    0.02147        277        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06098    0.04639    0.02146        227        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06097    0.04639    0.02146        163        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06096    0.04638    0.02145        127        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06095    0.04637    0.02145        157        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06094    0.04637    0.02145        242        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06093    0.04637    0.02145        243        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06092    0.04636    0.02144        174        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06091    0.04636    0.02144        188        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06089    0.04635    0.02143        189        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06088    0.04635    0.02143        158        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06087    0.04634    0.02143        190        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06086    0.04634    0.02142        231        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06085    0.04634    0.02142        213        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06084    0.04633    0.02142        179        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06082    0.04633    0.02142        250        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06081    0.04633    0.02141        240        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G     0.0608    0.04633    0.02141        221        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/1         0G    0.06079    0.04632     0.0214        179        416:  /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ^C
#         0/1         0G    0.06079    0.04632     0.0214        179        416:
# Traceback (most recent call last):
#   File "/home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py", line 986, in <module>
#     main(opt)
#   File "/home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py", line 688, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/train.py", line 421, in train
#     scaler.scale(loss).backward()
#   File "/home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages/torch/_tensor.py", line 581, in backward
#     torch.autograd.backward(
#   File "/home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages/torch/autograd/__init__.py", line 347, in backward
#     _engine_run_backward(
#   File "/home/venky/miniconda3/envs/plc_projects/lib/python3.10/site-packages/torch/autograd/graph.py", line 825, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt

# %% [markdown]
# #  **5. Evaluate the Model**

# %%
# !python val.py --weights runs/train/exp4/weights/best.pt --data Detrac_File/detrac.yaml --img 416
# Out:
# 48424.95s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# val: data=Detrac_File/detrac.yaml, weights=['runs/train/exp4/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-388-g882c35fc Python-3.10.15 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /home/venky/Documents/class/Application_of_neural_networks/Project
#                  Class     Images  Instances          P          R      mAP50
#                    all      56340     675774      0.799      0.475      0.522      0.352
#                 class0      56340      16915          1          0     0.0523     0.0366
#                 class1      56340     548555      0.699      0.738      0.758      0.496
#                 class2      56340      38519      0.695      0.402      0.483      0.339
#                 class3      56340      71785        0.8      0.761      0.797      0.537
# Speed: 0.2ms pre-process, 19.3ms inference, 0.9ms NMS per image at shape (32, 3, 416, 416)
# Results saved to runs/val/exp4

# %%
# %cd yolov5
# Out:
# /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5

# %%
# Install YOLOv5 (if not already installed)
# !pip install -U git+https://github.com/ultralytics/yolov5.git

import os
import torch
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Ensure matplotlib works in the notebook
# %matplotlib inline

# Define the custom weights path
custom_weights_path = 'runs/train/exp4/weights/best.pt'

# Check if the custom weights file exists
if not os.path.exists(custom_weights_path):
    print(f"Custom weights not found at '{custom_weights_path}'. Using a pre-trained YOLOv5 model instead.")
    model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
else:
    # Load custom-trained YOLOv5 model
    model = torch.hub.load('ultralytics/yolov5', 'custom', path=custom_weights_path, force_reload=True)

# Define the path to the video
video_path = 'input/Traffic.mp4'  # Replace with your video path

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if the video opened successfully
if not cap.isOpened():
    print(f"Error: Could not open video at '{video_path}'.")
    cap.release()
    exit()

frame_count = 0
total_vehicles = 0  # Initialize total vehicle counter

while True:
    ret, frame = cap.read()
    if not ret:
        print("End of video.")
        break

    # Perform inference
    results = model(frame)
    
    # Get the number of vehicles detected in the current frame
    vehicle_count = len(results.xyxy[0]) if results.xyxy else 0
    total_vehicles += vehicle_count  # Update the total vehicle count

    # Convert BGR to RGB for matplotlib display
    img = cv2.cvtColor(np.squeeze(results.render()), cv2.COLOR_BGR2RGB)

    # Display the frame with YOLOv5 detections
    plt.imshow(img)
    plt.title(f"Frame {frame_count}: {vehicle_count} vehicles detected")
    plt.axis('off')
    plt.show()  # Display in Jupyter Notebook

    # Clear the plot to avoid overlap in subsequent iterations
    plt.clf()
    
    frame_count += 1
    if frame_count >= 10:  # Display first 10 frames for example
        break

cap.release()

# Print the total number of vehicles detected across all frames
print(f"Total vehicles detected: {total_vehicles}")
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/venky/.cache/torch/hub/master.zip
# YOLOv5 🚀 2024-12-3 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 5898MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# /home/venky/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/venky/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/venky/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/venky/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/venky/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/venky/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/venky/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/venky/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/venky/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Total vehicles detected: 86
# /home/venky/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %% [markdown]
# # Video Conversion Using ffmpeg

# %%
# !ffmpeg -i input/Traffic4.mp4 -c:v libx264 -preset fast -crf 22 output4.mp4
# Out:
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input/Traffic4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.3.100
#   Duration: 00:15:00.12, start: 0.000000, bitrate: 710 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 854x480 [SAR 1:1 DAR 427:240], 574 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x6314ec5e1c40] using SAR=1/1
# [libx264 @ 0x6314ec5e1c40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x6314ec5e1c40] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x6314ec5e1c40] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=22.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 854x480 [SAR 1:1 DAR 427:240], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x6314ec26d7c0] video:118934kB audio:14101kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.710775%
# frame=27002 fps=571 q=-1.0 Lsize=  133981kB time=00:15:00.09 bitrate=1219.4kbits/s speed=  19x
# [libx264 @ 0x6314ec5e1c40] frame I:109   Avg QP:19.59  size: 66437
# [libx264 @ 0x6314ec5e1c40] frame P:8371  Avg QP:22.77  size: 10120
# [libx264 @ 0x6314ec5e1c40] frame B:18522 Avg QP:27.83  size:  1611
# [libx264 @ 0x6314ec5e1c40] consecutive B-frames:  2.9% 12.4% 13.8% 70.9%
# [libx264 @ 0x6314ec5e1c40] mb I  I16..4:  4.5% 47.8% 47.7%
# [libx264 @ 0x6314ec5e1c40] mb P  I16..4:  1.2%  2.7%  1.8%  P16..4: 34.5% 19.2% 12.0%  0.0%  0.0%    skip:28.5%
# [libx264 @ 0x6314ec5e1c40] mb B  I16..4:  0.4%  0.4%  0.1%  B16..8: 23.4%  6.5%  0.9%  direct: 1.9%  skip:66.4%  L0:43.8% L1:44.7% BI:11.6%
# [libx264 @ 0x6314ec5e1c40] 8x8 transform intra:46.6% inter:41.3%
# [libx264 @ 0x6314ec5e1c40] coded y,uvDC,uvAC intra: 58.5% 47.8% 14.1% inter: 11.0% 4.4% 0.1%
# [libx264 @ 0x6314ec5e1c40] i16 v,h,dc,p: 19% 36% 20% 25%
# [libx264 @ 0x6314ec5e1c40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 29% 23%  4%  4%  4%  5%  5%  6%
# [libx264 @ 0x6314ec5e1c40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 29% 15%  5%  6%  6%  7%  6%  7%
# [libx264 @ 0x6314ec5e1c40] i8c dc,h,v,p: 55% 25% 15%  5%
# [libx264 @ 0x6314ec5e1c40] Weighted P-Frames: Y:6.0% UV:0.7%
# [libx264 @ 0x6314ec5e1c40] ref P L0: 78.9% 21.1%
# [libx264 @ 0x6314ec5e1c40] ref B L0: 86.7% 13.3%
# [libx264 @ 0x6314ec5e1c40] ref B L1: 96.7%  3.3%
# [libx264 @ 0x6314ec5e1c40] kb/s:1082.48
# [aac @ 0x6314ec57dfc0] Qavg: 955.023

# %% [markdown]
# # **Example Code to Simulate Traffic Signal Management:**

# %%
import torch
import cv2
import numpy as np
import time
import matplotlib.pyplot as plt

# Simulate traffic signals for 4 roads
traffic_signals = {
    'road_1': {'vehicles': 0, 'signal': 'RED'},
    'road_2': {'vehicles': 0, 'signal': 'RED'},
    'road_3': {'vehicles': 0, 'signal': 'RED'},
    'road_4': {'vehicles': 0, 'signal': 'RED'}
}

# Function to update traffic lights based on vehicle count
def update_traffic_signals():
    print("\nUpdating Traffic Signals...")
    # Sort roads by vehicle count (most to least vehicles)
    sorted_roads = sorted(traffic_signals, key=lambda x: traffic_signals[x]['vehicles'], reverse=True)
    
    # Set the first road with the most vehicles to green, others to red
    for road in traffic_signals:
        if road == sorted_roads[0]:
            traffic_signals[road]['signal'] = 'GREEN'
        else:
            traffic_signals[road]['signal'] = 'RED'
    
    print("Traffic Signal Update:")
    for road, info in traffic_signals.items():
        print(f"  {road}: Signal = {info['signal']}, Vehicles = {info['vehicles']}")

# Load the trained model
print("Loading YOLOv5 model...")
model = torch.hub.load('ultralytics/yolov5', 'custom', path='runs/train/exp4/weights/best.pt')
print("Model loaded successfully!")

# Simulate each road with its own video feed
video_paths = {
    'road_1': '/kaggle/input/videotraffic/Traffic.mp4',
    'road_2': '/kaggle/input/videotraffic/Traffic2.mp4',
    'road_3': '/kaggle/input/videotraffic/Traffic3.mp4',
    'road_4': '/kaggle/input/videotraffic/Traffic4.mp4'
}

# Initialize video captures
caps = {road: cv2.VideoCapture(path) for road, path in video_paths.items()}

# Function to skip frames based on the video FPS and the required skip time (3 seconds)
def skip_frames(caps, skip_time):
    for road, cap in caps.items():
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        skip_frames = int(fps * skip_time)
        for _ in range(skip_frames):
            cap.grab()

# Process video frames
skip_time = 3  # Skip 3 seconds of video
iterations = 10  # Number of iterations

for iteration in range(iterations):
    print(f"\nIteration {iteration + 1}")
    for road, cap in caps.items():
        # Read a frame from the video feed
        ret, frame = cap.read()
        if not ret:
            print(f"  End of video for {road}")
            continue
        
        # Perform inference to detect vehicles
        print(f"  Detecting vehicles on {road}...")
        results = model(frame)
        vehicle_count = len(results.xyxy[0])
        
        # Update vehicle count for the road
        traffic_signals[road]['vehicles'] = vehicle_count
        print(f"  {road}: {vehicle_count} vehicles detected")
        
        # Render the results on the frame
        rendered_frame = results.render()[0]  # Render the bounding boxes and labels
        
        # Convert BGR frame to RGB for Matplotlib
        rendered_frame_rgb = cv2.cvtColor(rendered_frame, cv2.COLOR_BGR2RGB)
        
        # Display the frame using Matplotlib
        plt.figure(figsize=(10, 6))
        plt.imshow(rendered_frame_rgb)
        plt.title(f'{road} Frame with Detection')
        plt.axis('off')
        plt.show()
    
    # Skip frames equivalent to 3 seconds for each video
    skip_frames(caps, skip_time)
    
    # Update traffic signals based on vehicle count
    update_traffic_signals()
    
    # Introduce a delay of 1 second between each iteration
    time.sleep(1)  # Delay of 1 second before processing the next frame

# Release video captures
for cap in caps.values():
    cap.release()

print("End of program")
# Out:
# Loading YOLOv5 model...
# Using cache found in /home/venky/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-12-10 Python-3.10.15 torch-2.5.1+cu124 CPU
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:70, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      69 try:
# ---> 70     model = DetectMultiBackend(path, device=device, fuse=autoshape)  # detection model
#      71     if autoshape:
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:489, in DetectMultiBackend.__init__(self, weights, device, dnn, data, fp16, fuse)
#     488 if pt:  # PyTorch
# --> 489     model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
#     490     stride = max(int(model.stride.max()), 32)  # model stride
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/models/experimental.py:98, in attempt_load(weights, device, inplace, fuse)
#      97 for w in weights if isinstance(weights, list) else [weights]:
# ---> 98     ckpt = torch.load(attempt_download(w), map_location="cpu")  # load
#      99     ckpt = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File ~/miniconda3/envs/plc_projects/lib/python3.10/site-packages/ultralytics/utils/patches.py:86, in torch_load(*args, **kwargs)
#      84     kwargs["weights_only"] = False
# ---> 86 return _torch_load(*args, **kwargs)
#
# File ~/miniconda3/envs/plc_projects/lib/python3.10/site-packages/torch/serialization.py:1319, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1317     pickle_load_args["encoding"] = "utf-8"
# -> 1319 with _open_file_like(f, "rb") as opened_file:
#    1320     if _is_zipfile(opened_file):
#    1321         # The zipfile reader is going to advance the current file position.
#    1322         # If we want to actually tail call to torch.jit.load, we need to
#    1323         # reset back to the original position.
#
# File ~/miniconda3/envs/plc_projects/lib/python3.10/site-packages/torch/serialization.py:659, in _open_file_like(name_or_buffer, mode)
#     658 if _is_path(name_or_buffer):
# --> 659     return _open_file(name_or_buffer, mode)
#     660 else:
#
# File ~/miniconda3/envs/plc_projects/lib/python3.10/site-packages/torch/serialization.py:640, in _open_file.__init__(self, name, mode)
#     639 def __init__(self, name, mode):
# --> 640     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/train/exp4/weights/best.pt'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:85, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      84     except Exception:
# ---> 85         model = attempt_load(path, device=device, fuse=False)  # arbitrary model
#      86 else:
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/models/experimental.py:98, in attempt_load(weights, device, inplace, fuse)
#      97 for w in weights if isinstance(weights, list) else [weights]:
# ---> 98     ckpt = torch.load(attempt_download(w), map_location="cpu")  # load
#      99     ckpt = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File ~/miniconda3/envs/plc_projects/lib/python3.10/site-packages/ultralytics/utils/patches.py:86, in torch_load(*args, **kwargs)
#      84     kwargs["weights_only"] = False
# ---> 86 return _torch_load(*args, **kwargs)
#
# File ~/miniconda3/envs/plc_projects/lib/python3.10/site-packages/torch/serialization.py:1319, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1317     pickle_load_args["encoding"] = "utf-8"
# -> 1319 with _open_file_like(f, "rb") as opened_file:
#    1320     if _is_zipfile(opened_file):
#    1321         # The zipfile reader is going to advance the current file position.
#    1322         # If we want to actually tail call to torch.jit.load, we need to
#    1323         # reset back to the original position.
#
# File ~/miniconda3/envs/plc_projects/lib/python3.10/site-packages/torch/serialization.py:659, in _open_file_like(name_or_buffer, mode)
#     658 if _is_path(name_or_buffer):
# --> 659     return _open_file(name_or_buffer, mode)
#     660 else:
#
# File ~/miniconda3/envs/plc_projects/lib/python3.10/site-packages/torch/serialization.py:640, in _open_file.__init__(self, name, mode)
#     639 def __init__(self, name, mode):
# --> 640     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/train/exp4/weights/best.pt'
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 34
#      32 # Load the trained model
#      33 print("Loading YOLOv5 model...")
# ---> 34 model = torch.hub.load('ultralytics/yolov5', 'custom', path='runs/train/exp4/weights/best.pt')
#      35 print("Model loaded successfully!")
#      37 # Simulate each road with its own video feed
#
# File ~/miniconda3/envs/plc_projects/lib/python3.10/site-packages/torch/hub.py:647, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     637 if source == "github":
#     638     repo_or_dir = _get_cache_or_reload(
#     639         repo_or_dir,
#     640         force_reload,
#    (...)
#     644         skip_validation=skip_validation,
#     645     )
# --> 647 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     648 return model
#
# File ~/miniconda3/envs/plc_projects/lib/python3.10/site-packages/torch/hub.py:676, in _load_local(hubconf_dir, model, *args, **kwargs)
#     673     hub_module = _import_module(MODULE_HUBCONF, hubconf_path)
#     675     entry = _load_entry_from_hubconf(hub_module, model)
# --> 676     model = entry(*args, **kwargs)
#     678 return model
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:135, in custom(path, autoshape, _verbose, device)
#     106 def custom(path="path/to/model.pt", autoshape=True, _verbose=True, device=None):
#     107     """
#     108     Loads a custom or local YOLOv5 model from a given path with optional autoshaping and device specification.
#     109
#    (...)
#     133         ```
#     134     """
# --> 135     return _create(path, autoshape=autoshape, verbose=_verbose, device=device)
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:103, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#     101 help_url = "https://docs.ultralytics.com/yolov5/tutorials/pytorch_hub_model_loading"
#     102 s = f"{e}. Cache may be out of date, try `force_reload=True` or see {help_url} for help."
# --> 103 raise Exception(s) from e
#
# Exception: [Errno 2] No such file or directory: 'runs/train/exp4/weights/best.pt'. Cache may be out of date, try `force_reload=True` or see https://docs.ultralytics.com/yolov5/tutorials/pytorch_hub_model_loading for help.

# %% [markdown]
# # Converting the model to ONNX format.

# %%
# !python export.py --weights /home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/yolov5s.pt --img-size 416 --batch-size 1 --dynamic --include onnx
# Out:
# python: can't open file '/home/venky/Documents/class/Application_of_neural_networks/Project/export.py': [Errno 2] No such file or directory

# %%
# !sudo apt install python3-libnvinfer
# Out:
# [sudo] password for venky:

# %%
# !trtexec --onnx=/home/venky/Documents/class/Application_of_neural_networks/Project/yolov5/yolov5s.onnx --saveEngine=path_to_save_model.trt --fp16
# Out:
# /bin/bash: line 1: trtexec: command not found

# %% [markdown]
# Here is the markdown content for the steps to convert the YOLOv5 model to ONNX and optimize it using TensorRT. You can paste this directly into a Jupyter Notebook cell to render it as markdown.
#
# ```markdown
# # YOLOv5 Model Conversion to ONNX and Optimization with TensorRT
#
# ### Step 1: Install Required Libraries
# First, ensure that you have the necessary libraries installed:
# ```bash
# pip install torch onnx onnxruntime pycuda nvidia-pyindex
# ```
#
# For TensorRT, if you haven't installed it yet, use the following commands (assuming you are using NVIDIA Jetson with the JetPack SDK):
# ```bash
# sudo apt install python3-libnvinfer
# ```
#
# ### Step 2: Convert YOLOv5 Model to ONNX
# Use the YOLOv5 repository to convert the `.pt` model to the ONNX format.
#
# 1. **Clone YOLOv5 GitHub Repository (if not already cloned)**:
#    ```bash
#    git clone https://github.com/ultralytics/yolov5
#    cd yolov5
#    ```
#
# 2. **Run the Conversion Command**:
#    In the YOLOv5 directory, run the following command to convert the trained model (`yolov5.pt`) to the ONNX format:
#    ```bash
#    python export.py --weights path/to/yolov5.pt --img-size 416 --batch-size 1 --dynamic --include onnx
#    ```
#
#    - `path/to/yolov5.pt` should be replaced with the actual path to your `.pt` file.
#    - `--img-size 416` specifies the image size to resize inputs for the model (you can adjust it as per your training).
#    - `--batch-size 1` sets the batch size for the conversion process.
#    - `--dynamic` ensures that the exported ONNX model supports dynamic input shapes.
#    - `--include onnx` tells the script to convert to the ONNX format.
#
#    The command will create an `onnx` file in the `runs/` directory.
#
# ### Step 3: Optimize the ONNX Model using TensorRT
# Next, you need to optimize the ONNX model using TensorRT for faster inference, especially on NVIDIA GPUs.
#
# 1. **Install TensorRT (on Jetson Xavier NX)**:
#    - Ensure that TensorRT is installed via the JetPack SDK. If using Ubuntu, the following command should work:
#    ```bash
#    sudo apt-get install python3-libnvinfer
#    ```
#
# 2. **Convert ONNX Model to TensorRT Engine**:
#    - Use TensorRT's `trtexec` tool to optimize the ONNX model. The following command will convert the ONNX model into a TensorRT engine:
#    ```bash
#    trtexec --onnx=path_to_your_model.onnx --saveEngine=path_to_save_model.trt --fp16
#    ```
#
#    - `--onnx=path_to_your_model.onnx` specifies the ONNX model you want to optimize.
#    - `--saveEngine=path_to_save_model.trt` is the output path where the TensorRT engine will be saved.
#    - `--fp16` enables half-precision floating-point mode (FP16) to speed up inference on TensorRT-capable hardware like Jetson Xavier NX.
#
# 3. **Verify the TensorRT Engine**:
#    Once the model is optimized, you can use the generated TensorRT engine file for inference. You can verify its performance by running a Python script with TensorRT APIs.
#
# ### Step 4: Use TensorRT Model in Python
# To run inference using the optimized TensorRT model, you can use `pycuda` and `tensorrt` Python bindings.
#
# ```python
# import pycuda.driver as cuda
# import pycuda.autoinit
# import tensorrt as trt
# import numpy as np
#
# # Load TensorRT engine
# TRT_LOGGER = trt.Logger(trt.Logger.WARNING)
# with open('path_to_save_model.trt', 'rb') as f:
#     engine_data = f.read()
#     runtime = trt.Runtime(TRT_LOGGER)
#     engine = runtime.deserialize_cuda_engine(engine_data)
#
# # Create an execution context
# context = engine.create_execution_context()
#
# # Allocate memory for inputs/outputs
# input_shape = (1, 3, 416, 416)  # Adjust based on input size
# input_data = np.random.random(input_shape).astype(np.float32)
# d_input = cuda.mem_alloc(input_data.nbytes)
# cuda.memcpy_htod(d_input, input_data)
#
# # Perform inference
# output = np.empty([1, 25200, 85], dtype=np.float32)  # Adjust based on output layer size
# d_output = cuda.mem_alloc(output.nbytes)
# bindings = [int(d_input), int(d_output)]
# context.execute_v2(bindings)
#
# # Copy result from device to host
# cuda.memcpy_dtoh(output, d_output)
#
# print(output)
# ```
#
# - This script loads the optimized TensorRT model and performs inference on an input tensor (`input_data`).
# - Make sure to replace `path_to_save_model.trt` with the actual location where you saved the TensorRT engine.
#
# ---
#
# ### Summary of Steps:
# 1. **Convert YOLOv5 model to ONNX** using YOLOv5's `export.py`.
# 2. **Optimize ONNX model with TensorRT** using `trtexec` to generate the `.trt` engine.
# 3. **Run inference** on Jetson Xavier NX using TensorRT Python bindings and `pycuda`.
#
# By following these steps, you will have an optimized YOLOv5 model running on TensorRT for real-time inference on Jetson Xavier NX.
# ```
